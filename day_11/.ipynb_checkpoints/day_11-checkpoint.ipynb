# %% [markdown]
# # 11일차

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 행열곱 (가중치)

# %%
X= np.random.randint(11,size=[100,4])
X
# Out:
# array([[ 8,  0,  6,  9],
#        [ 1,  5,  6, 10],
#        [ 9,  6,  6,  3],
#        [ 4,  0,  9,  6],
#        [ 7,  3,  3,  4],
#        [10,  1,  9,  8],
#        [ 1,  1,  1,  0],
#        [ 1,  3,  1,  3],
#        [ 5,  4,  1,  7],
#        [ 6,  4,  9, 10],
#        [ 9,  0,  8,  9],
#        [ 5,  9,  1,  0],
#        [10,  4,  6,  0],
#        [ 8,  8,  6,  8],
#        [ 3,  1, 10,  3],
#        [ 3,  5,  2,  2],
#        [ 9,  1,  6,  2],
#        [ 3,  0,  6,  6],
#        [ 4,  4,  6,  2],
#        [10,  6,  6,  0],
#        [ 1,  6,  2,  6],
#        [ 3,  9,  3, 10],
#        [ 5,  2,  6,  1],
#        [ 9,  7,  9, 10],
#        [ 1,  3,  1,  3],
#        [ 0,  3,  0,  1],
#        [10,  0,  9,  4],
#        [ 6,  4,  9, 10],
#        [ 8,  0, 10,  5],
#        [ 7,  0,  2,  7],
#        [10,  7,  0,  2],
#        [ 3,  1,  0,  5],
#        [ 6,  0,  9,  1],
#        [ 3,  9,  8,  0],
#        [10, 10,  7,  0],
#        [ 6,  9,  7,  7],
#        [ 8,  6,  8, 10],
# ...

# %%
w1=np.random.randn(4,10)

# %%
y1=X@w1
y1.shape
# Out:
# (100, 10)

# %%
y1
# Out:
# array([[ 4.24817426e+00,  4.08773837e+00, -7.07709195e-01,
#          2.85649832e+00, -1.71565955e+01, -1.36446174e+01,
#         -4.04066061e+00,  1.03560865e+01,  2.22535920e+01,
#          2.35773735e+00],
#        [ 7.78627341e+00,  8.72621153e+00, -6.75931761e+00,
#          7.83129343e-01, -2.00216023e+01,  5.26501827e-01,
#         -5.11391473e-01, -2.12101299e+00,  2.00898598e+01,
#          9.14519428e+00],
#        [ 2.15956153e+01, -5.55405311e+00,  1.71686309e+01,
#          1.09861977e+01, -1.14745859e+01, -6.25383969e+00,
#         -6.14918265e-01,  1.06287275e+01,  1.07936584e+01,
#         -1.96183835e+00],
#        [-3.27239465e+00,  2.74122886e+00, -5.08156391e+00,
#          8.03120971e+00, -1.00276901e+01, -3.17201530e+00,
#         -2.86968447e+00, -1.29027421e+00,  1.60642345e+01,
#          3.54127315e+00],
#        [ 1.37944983e+01, -1.53026102e+00,  9.64135815e+00,
#          4.17576581e+00, -1.09148804e+01, -8.63605794e+00,
# ...

# %%
w2=np.random.randn(10,5)

# %%
y2=y1@w2
y2.shape
# Out:
# (100, 5)

# %%
y2
# Out:
# array([[ 5.64365820e+01, -3.42651967e+01, -1.43711767e+01,
#          2.58422912e+01, -3.28740914e+01],
#        [ 7.69011360e+01, -6.84103227e+01, -8.83283969e+00,
#          4.77108643e+01, -2.36778568e+01],
#        [ 3.54161888e+01, -9.76462645e+00, -3.24106667e+01,
#          3.68575302e+01, -1.93119556e+01],
#        [ 2.98256725e+01, -4.13934094e+01, -1.14614277e+01,
#          2.79474577e+00, -4.76671299e+00],
#        [ 3.59156209e+01, -8.76229300e+00, -1.92349948e+01,
#          3.02299711e+01, -2.41114963e+01],
#        [ 4.93421579e+01, -3.26978196e+01, -2.38062701e+01,
#          2.19941466e+01, -2.65275682e+01],
#        [ 2.26119284e+00, -8.51441787e-01, -4.79584550e+00,
#          3.78268051e+00, -3.27555564e-01],
#        [ 2.94654904e+01, -1.78904497e+01, -6.13389980e+00,
#          2.50293932e+01, -1.21539484e+01],
#        [ 6.18950288e+01, -2.53832726e+01, -1.28516474e+01,
#          4.91491746e+01, -3.60562693e+01],
# ...

# %%
w3=np.random.randn(5,1)

# %%
y=y2@w3
y.shape
# Out:
# (100, 1)

# %%
y
# Out:
# array([[ 88.10620351],
#        [ 61.8160025 ],
#        [ 82.95276811],
#        [ 22.47955537],
#        [ 76.75129516],
#        [ 85.79563665],
#        [  6.77047913],
#        [ 34.48231291],
#        [ 95.17819058],
#        [ 80.52342652],
#        [ 85.42508884],
#        [ 71.65877084],
#        [ 62.95096745],
#        [115.75443141],
#        [ -5.36982571],
#        [ 46.81891374],
#        [ 55.27273727],
#        [ 30.35624394],
#        [ 29.49063138],
#        [ 71.46300726],
#        [ 61.25459269],
#        [109.84687004],
#        [ 22.28869337],
#        [116.42158559],
#        [ 34.48231291],
#        [ 19.16799103],
#        [ 55.93989145],
#        [ 80.52342652],
#        [ 41.72418264],
#        [ 88.37860332],
#        [119.69233317],
#        [ 59.38577588],
#        [  5.899965  ],
#        [ 19.86968734],
#        [ 83.29151298],
#        [ 92.99487986],
#        [109.65110646],
#        [109.26938245],
#        [140.06468164],
#        [ 57.58060933],
# ...
