# %% [markdown]
# # 12일차
# ## 파이썬 데이터 분석
#
# ### PANDAS
#
# ### 연습문제
#
# - 'world_happiness_report_2021.csv' 를 DataFrame 으로 불러오시오.
# - 칼럼명을 리스트로 변환하시오.
# - 행의 갯수와 열의 갯수를 구하시오.
# - 나라이름을 뽑으시오.
# - 나라이름과 행복지수(Ladder core)를 뽑으시오.
# - 'Ladder score' 와 'Logged GDP per capita' 를 뽑아 넘파이 어레이로 변환하시오.
# - 처음 다섯 행을 뽑으시오.
# - 마지막 다섯 행을 뽑으시오.
# - 처음 다섯행과 마지막 다섯행을 한번에 뽑는 방법을 생각해 보시오.
# - 'Reginal indicator' 를 코드화 시키시오. (set 또는 numpy unique() 함수 사용)
# - 'Logged GDP per capita' 값에 지수함수를 적용한 값을 'gdp' 라는 새로운 칼럼으로 추가하시오. (np.exp() 함수 적용)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('world_happiness_report_2021.csv')
data
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
features=list(data.columns)
features
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual']

# %%
data.columns.to_list()
# Out:
# ['Country name',
#  'Regional indicator',
#  'Ladder score',
#  'Standard error of ladder score',
#  'upperwhisker',
#  'lowerwhisker',
#  'Logged GDP per capita',
#  'Social support',
#  'Healthy life expectancy',
#  'Freedom to make life choices',
#  'Generosity',
#  'Perceptions of corruption',
#  'Ladder score in Dystopia',
#  'Explained by: Log GDP per capita',
#  'Explained by: Social support',
#  'Explained by: Healthy life expectancy',
#  'Explained by: Freedom to make life choices',
#  'Explained by: Generosity',
#  'Explained by: Perceptions of corruption',
#  'Dystopia + residual']

# %%
dict(enumerate(features))
# Out:
# {0: 'Country name',
#  1: 'Regional indicator',
#  2: 'Ladder score',
#  3: 'Standard error of ladder score',
#  4: 'upperwhisker',
#  5: 'lowerwhisker',
#  6: 'Logged GDP per capita',
#  7: 'Social support',
#  8: 'Healthy life expectancy',
#  9: 'Freedom to make life choices',
#  10: 'Generosity',
#  11: 'Perceptions of corruption',
#  12: 'Ladder score in Dystopia',
#  13: 'Explained by: Log GDP per capita',
#  14: 'Explained by: Social support',
#  15: 'Explained by: Healthy life expectancy',
#  16: 'Explained by: Freedom to make life choices',
#  17: 'Explained by: Generosity',
#  18: 'Explained by: Perceptions of corruption',
#  19: 'Dystopia + residual'}

# %%
data.shape
# Out:
# (149, 20)

# %%
len(data)
# Out:
# 149

# %%
len(data.columns)
# Out:
# 20

# %%
data['Country name']
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %%
country_code=dict(data['Country name'])
country_code
# Out:
# {0: 'Finland',
#  1: 'Denmark',
#  2: 'Switzerland',
#  3: 'Iceland',
#  4: 'Netherlands',
#  5: 'Norway',
#  6: 'Sweden',
#  7: 'Luxembourg',
#  8: 'New Zealand',
#  9: 'Austria',
#  10: 'Australia',
#  11: 'Israel',
#  12: 'Germany',
#  13: 'Canada',
#  14: 'Ireland',
#  15: 'Costa Rica',
#  16: 'United Kingdom',
#  17: 'Czech Republic',
#  18: 'United States',
#  19: 'Belgium',
#  20: 'France',
#  21: 'Bahrain',
#  22: 'Malta',
#  23: 'Taiwan Province of China',
#  24: 'United Arab Emirates',
#  25: 'Saudi Arabia',
#  26: 'Spain',
#  27: 'Italy',
#  28: 'Slovenia',
#  29: 'Guatemala',
#  30: 'Uruguay',
#  31: 'Singapore',
#  32: 'Kosovo',
#  33: 'Slovakia',
#  34: 'Brazil',
#  35: 'Mexico',
#  36: 'Jamaica',
#  37: 'Lithuania',
#  38: 'Cyprus',
#  39: 'Estonia',
#  40: 'Panama',
#  41: 'Uzbekistan',
#  42: 'Chile',
#  43: 'Poland',
#  44: 'Kazakhstan',
#  45: 'Romania',
#  46: 'Kuwait',
#  47: 'Serbia',
#  48: 'El Salvador',
#  49: 'Mauritius',
#  50: 'Latvia',
#  51: 'Colombia',
# ...

# %%
{v:k for k,v in country_code.items()}
# Out:
# {'Finland': 0,
#  'Denmark': 1,
#  'Switzerland': 2,
#  'Iceland': 3,
#  'Netherlands': 4,
#  'Norway': 5,
#  'Sweden': 6,
#  'Luxembourg': 7,
#  'New Zealand': 8,
#  'Austria': 9,
#  'Australia': 10,
#  'Israel': 11,
#  'Germany': 12,
#  'Canada': 13,
#  'Ireland': 14,
#  'Costa Rica': 15,
#  'United Kingdom': 16,
#  'Czech Republic': 17,
#  'United States': 18,
#  'Belgium': 19,
#  'France': 20,
#  'Bahrain': 21,
#  'Malta': 22,
#  'Taiwan Province of China': 23,
#  'United Arab Emirates': 24,
#  'Saudi Arabia': 25,
#  'Spain': 26,
#  'Italy': 27,
#  'Slovenia': 28,
#  'Guatemala': 29,
#  'Uruguay': 30,
#  'Singapore': 31,
#  'Kosovo': 32,
#  'Slovakia': 33,
#  'Brazil': 34,
#  'Mexico': 35,
#  'Jamaica': 36,
#  'Lithuania': 37,
#  'Cyprus': 38,
#  'Estonia': 39,
#  'Panama': 40,
#  'Uzbekistan': 41,
#  'Chile': 42,
#  'Poland': 43,
#  'Kazakhstan': 44,
#  'Romania': 45,
#  'Kuwait': 46,
#  'Serbia': 47,
#  'El Salvador': 48,
#  'Mauritius': 49,
#  'Latvia': 50,
#  'Colombia': 51,
# ...

# %%
a=data[['Ladder score','Logged GDP per capita']].values
a
# Out:
# array([[ 7.842, 10.775],
#        [ 7.62 , 10.933],
#        [ 7.571, 11.117],
#        [ 7.554, 10.878],
#        [ 7.464, 10.932],
#        [ 7.392, 11.053],
#        [ 7.363, 10.867],
#        [ 7.324, 11.647],
#        [ 7.277, 10.643],
#        [ 7.268, 10.906],
#        [ 7.183, 10.796],
#        [ 7.157, 10.575],
#        [ 7.155, 10.873],
#        [ 7.103, 10.776],
#        [ 7.085, 11.342],
#        [ 7.069,  9.88 ],
#        [ 7.064, 10.707],
#        [ 6.965, 10.556],
#        [ 6.951, 11.023],
#        [ 6.834, 10.823],
#        [ 6.69 , 10.704],
#        [ 6.647, 10.669],
#        [ 6.602, 10.674],
#        [ 6.584, 10.871],
#        [ 6.561, 11.085],
#        [ 6.494, 10.743],
#        [ 6.491, 10.571],
#        [ 6.483, 10.623],
#        [ 6.461, 10.529],
#        [ 6.435,  9.053],
#        [ 6.431,  9.966],
#        [ 6.377, 11.488],
#        [ 6.372,  9.318],
#        [ 6.331, 10.369],
#        [ 6.33 ,  9.577],
#        [ 6.317,  9.859],
#        [ 6.309,  9.186],
# ...

# %%
plt.scatter(a[:,0],a[:,1])
plt.xlabel('ladder score')
plt.ylabel('logged gdp')
# Out:
# Text(0, 0.5, 'logged gdp')

# %%
data['Country name']
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %%
for i in range(149):
    if data['Country name'][i].upper().find('KOREA')>0:
        print(i,data['Country name'][i])
# Out:
# 61 South Korea

# %%
data['Ladder score'][61]
# Out:
# 5.845

# %%
data['Ladder score'].mean()
# Out:
# 5.532838926174494

# %%
data.iloc[61,2]
# Out:
# 5.845

# %%
data[:5]
# Out:
#   Country name Regional indicator  Ladder score  \
# 0      Finland     Western Europe         7.842
# 1      Denmark     Western Europe         7.620
# 2  Switzerland     Western Europe         7.571
# 3      Iceland     Western Europe         7.554
# 4  Netherlands     Western Europe         7.464
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 0                 10.775           0.954                     72.0
# 1                 10.933           0.954                     72.7
# 2                 11.117           0.942                     74.4
# ...

# %%
data.iloc[list(range(5))+list(range(-5,0))]
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# 4                             0.027         7.518         7.410
# ...

# %%
rc=sorted(list(set(data['Regional indicator'])))
rc
# Out:
# ['Central and Eastern Europe',
#  'Commonwealth of Independent States',
#  'East Asia',
#  'Latin America and Caribbean',
#  'Middle East and North Africa',
#  'North America and ANZ',
#  'South Asia',
#  'Southeast Asia',
#  'Sub-Saharan Africa',
#  'Western Europe']

# %%
{v:i for i,v in enumerate(rc)}
# Out:
# {'Central and Eastern Europe': 0,
#  'Commonwealth of Independent States': 1,
#  'East Asia': 2,
#  'Latin America and Caribbean': 3,
#  'Middle East and North Africa': 4,
#  'North America and ANZ': 5,
#  'South Asia': 6,
#  'Southeast Asia': 7,
#  'Sub-Saharan Africa': 8,
#  'Western Europe': 9}

# %%
r=np.log([10,100,1000,10000])
r
# Out:
# array([2.30258509, 4.60517019, 6.90775528, 9.21034037])

# %%
np.exp(r)
# Out:
# array([1.e+01, 1.e+02, 1.e+03, 1.e+04])

# %%
gdp = np.exp(data['Logged GDP per capita'])
gdp
# Out:
# 0      47810.473244
# 1      55994.010016
# 2      67305.686038
# 3      52997.498855
# 4      55938.043994
#            ...
# 144     2768.331303
# 145    17712.041536
# 146     2155.978587
# 147     2815.795236
# 148     2197.333810
# Name: Logged GDP per capita, Length: 149, dtype: float64

# %%
data2=data.copy()
data2['gdp']=np.exp(data['Logged GDP per capita'])

# %%
data2
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
plt.figure(figsize=[12,6])
plt.subplot(1,2,1)
plt.scatter(data2.gdp,data2['Ladder score'])
plt.subplot(1,2,2)
plt.scatter(data2['Logged GDP per capita'],data2['Ladder score'])

# %% [markdown]
# ### pandas 기초

# %%
data = pd.DataFrame([['홍길동',99,'1999/1/1'],
                    ['한희구',85,'1996/6/20'],
                    ['둘리',51,'2005/1/1']],
                   columns=['이름','성적','생일'])
data
# Out:
#     이름  성적         생일
# 0  홍길동  99   1999/1/1
# 1  한희구  85  1996/6/20
# 2   둘리  51   2005/1/1

# %%
data.이름
# Out:
# 0    홍길동
# 1    한희구
# 2     둘리
# Name: 이름, dtype: object

# %%
data.이름.to_frame()
# Out:
#     이름
# 0  홍길동
# 1  한희구
# 2   둘리

# %%
data[['이름']]
# Out:
#     이름
# 0  홍길동
# 1  한희구
# 2   둘리

# %%
a=np.array([[1,2],[3,4],[5,6]])
a[[0]]
# Out:
# array([[1, 2]])

# %%
data=pd.DataFrame({'국어':[99,76,86,63],
                  '영어':[88,89,95,76],
                  '지역':['서울','부산','원주','서울']})
data
# Out:
#    국어  영어  지역
# 0  99  88  서울
# 1  76  89  부산
# 2  86  95  원주
# 3  63  76  서울

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국어      4 non-null      int64
#  1   영어      4 non-null      int64
#  2   지역      4 non-null      object
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
code=np.sort(data.지역.unique())
code
# Out:
# array(['부산', '서울', '원주'], dtype=object)

# %%
c={}
for i in range(len(code)):
    c[code[i]]=i
c
# Out:
# {'부산': 0, '서울': 1, '원주': 2}

# %%
data['코드']=data.지역.map(c)
data
# Out:
#    국어  영어  지역  코드
# 0  99  88  서울   1
# 1  76  89  부산   0
# 2  86  95  원주   2
# 3  63  76  서울   1

# %%
data2=data.copy()
data2['코드']=data.지역.map(lambda x: list(code).index(x))
data2
# Out:
#    국어  영어  지역  코드
# 0  99  88  서울   1
# 1  76  89  부산   0
# 2  86  95  원주   2
# 3  63  76  서울   1

# %%
X=data[['국어','영어','코드']].values
X
# Out:
# array([[99, 88,  1],
#        [76, 89,  0],
#        [86, 95,  2],
#        [63, 76,  1]], dtype=int64)

# %%
X2=X/[100,100,1]
X2
# Out:
# array([[0.99, 0.88, 1.  ],
#        [0.76, 0.89, 0.  ],
#        [0.86, 0.95, 2.  ],
#        [0.63, 0.76, 1.  ]])

# %%
plt.scatter(X2[:,0],X2[:,1],c=X2[:,2])

# %%
data=pd.DataFrame({'시':['서울','서울','서울','부산'],
                  '구':['구로구','구로구','관악구','해운대구'],
                  '값':[75,83,69,97]})
data
# Out:
#     시     구   값
# 0  서울   구로구  75
# 1  서울   구로구  83
# 2  서울   관악구  69
# 3  부산  해운대구  97

# %%
data = pd.DataFrame([['홍길동',99,'1999/1/1'],
                    ['한희구',85,'1996/6/20'],
                    ['둘리',51,'2005/1/1']],
                   columns=['이름','성적','생일'])
data
# Out:
#     이름  성적         생일
# 0  홍길동  99   1999/1/1
# 1  한희구  85  1996/6/20
# 2   둘리  51   2005/1/1

# %%
pd.to_datetime(data.생일)
# Out:
# 0   1999-01-01
# 1   1996-06-20
# 2   2005-01-01
# Name: 생일, dtype: datetime64[ns]

# %%
pd.to_datetime(['1/1/2021','1/31/2021'])
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-31'], dtype='datetime64[ns]', freq=None)

# %%
data['날짜']=pd.to_datetime(data.생일)
data
# Out:
#     이름  성적         생일         날짜
# 0  홍길동  99   1999/1/1 1999-01-01
# 1  한희구  85  1996/6/20 1996-06-20
# 2   둘리  51   2005/1/1 2005-01-01

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      3 non-null      object
#  1   성적      3 non-null      int64
#  2   생일      3 non-null      object
#  3   날짜      3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(1), object(2)
# memory usage: 224.0+ bytes

# %%
pd.to_datetime('20210721',format='%Y%m%d')
# Out:
# Timestamp('2021-07-21 00:00:00')

# %%
subway=pd.read_csv('CARD_SUBWAY_MONTH_202106.csv')
subway
# Out:
#          사용일자           노선명     역명  승차총승객수    하차총승객수  등록일자
# 20210601  3호선            신사  28955   30583  20210604   NaN
# 20210601  3호선            잠원   4780    4656  20210604   NaN
# 20210601  3호선         고속터미널  33986   32532  20210604   NaN
# 20210601  3호선    교대(법원.검찰청)  14136    9362  20210604   NaN
# 20210601  3호선  남부터미널(예술의전당)  27604   28821  20210604   NaN
# ...       ...           ...    ...     ...       ...   ...
# 20210630  1호선           서울역  42545   39641  20210703   NaN
# 20210630  8호선            신흥   4343    4713  20210703   NaN
# 20210630  분당선            망포  14451   13503  20210703   NaN
# 20210630  분당선          매탄권선   5121    4907  20210703   NaN
# 20210630  분당선          수원시청  12344   13336  20210703   NaN
#
# [18035 rows x 6 columns]
